# %% [markdown]
# ## Install Vertex AI SDK for Python

# %%
# !pip install --upgrade --user google-cloud-aiplatform -q
# !pip uninstall numpy -y -q
# !pip install numpy -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 18.4 MB/s eta 0:00:00
#   WARNING: The script tb-gcp-uploader is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 68.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.

# %%
# !pip install ragstack-ai -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 29.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.0/990.0 kB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 71.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.5/373.5 kB 25.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.5/15.5 MB 92.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.1/186.1 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.1/679.1 kB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 75.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 50.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.8/314.8 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 68.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.7/862.7 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.4/207.4 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 22.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.4/115.4 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.0 MB/s eta 0:00:00
#   Building wheel for colbert-ai (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.1 which is incompatible.
# bigframes 2.4.0 requires pyarrow>=15.0.2, but you have pyarrow 14.0.1 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.1 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.

# %%
PROJECT_ID = "vertex-234234234"
LOCATION = "us-central1"

# %%
ASTRA_DB_API_ENDPOINT="https://23423423424323-34234234234-4639-a817-c2249831b4d4-us-east-2.apps.astra.datastax.com"
ASTRA_DB_APPLICATION_TOKEN="AstraCS:23423234323243232:1c511caccd5a7b6f85fd727d33f4367c615c55aacc86a60ec51bbb6089fe3644"

# %%
import getpass, os, requests

if "GCP_PROJECT_ID" not in os.environ:
  os.environ["GCP_PROJECT_ID"] =  PROJECT_ID # getpass.getpass("Provide your GCP Project ID")

if "LOCATION" not in os.environ:
  os.environ["LOCATION"] =  LOCATION # getpass.getpass("Provide your GCP Location")

if "ASTRA_DB_ENDPOINT" not in os.environ:
  os.environ["ASTRA_DB_ENDPOINT"] =  ASTRA_DB_API_ENDPOINT

if "ASTRA_DB_TOKEN" not in os.environ:
  os.environ["ASTRA_DB_TOKEN"] = ASTRA_DB_APPLICATION_TOKEN

# %% [markdown]
# ## Authenticate your notebook environment ( Colab only )

# %%
# !gcloud config set project {os.getenv("GCP_PROJECT_ID")}
# Out:
# Updated property [core/project].

# %%
import sys

# Additional authentication is required for Google Colab
if "google.colab" in sys.modules:
    # Authenticate user to Google Cloud
    from google.colab import auth

    auth.authenticate_user()

# %%
# !gcloud auth list
# Out:
#      Credentialed Accounts
# ACTIVE  ACCOUNT
# *       shivdutta2404@gmail.com
#
# To set the active account, run:
#     $ gcloud config set account `ACCOUNT`

# %% [markdown]
# ## Set Google Cloud project information and initialize Vertex AI SDK

# %%
# Initialize Vertex AI
import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION)

# %% [markdown]
# ## Import libraries

# %%
from vertexai.preview.generative_models import (
    GenerationConfig,
    GenerativeModel,
    HarmCategory,
    HarmBlockThreshold,
    Image,
    Part
)

# %% [markdown]
# ## Use the Gemini 1.0 Pro model
#
# The Gemini 1.0 Pro (`gemini-1.0-pro`) model is designed to handle natural language tasks, multi-turn text and code chat, and code generation.

# %% [markdown]
# ## Load the Gemini 1.0 Pro model

# %%
model = GenerativeModel("gemini-2.0-flash-001")

# %% [markdown]
# ## Generate text from text prompts

# %%
responses = model.generate_content("Why is the sky blue?", stream=True)

# %%
for response in responses:
    print(response.text, end="")
# Out:
# The sky is blue due to a phenomenon called **Rayleigh scattering**. Here's a breakdown:
#
# * **Sunlight and its Colors:** Sunlight appears white, but it's actually made up of all the colors of the rainbow (red, orange, yellow, green, blue, indigo, violet).
#
# * **Entering the Atmosphere:** When sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen).
#
# * **Scattering of Light:** This collision causes the light to scatter in different directions.
#
# * **Rayleigh Scattering in Action:**  Rayleigh scattering is more effective at scattering shorter wavelengths of light.  Blue and violet light have shorter wavelengths than other colors like red and orange.
#
# * **Why Blue and Not Violet?** While violet light has an even shorter wavelength than blue, the sun emits less violet light.  Additionally, our eyes are more sensitive to blue light than violet light.  Therefore, we see the sky as predominantly blue.
#
# * **Sunsets and Sunrises:** At sunrise and sunset, the sunlight has to travel through much more of the atmosphere to reach our eyes.  This longer path means that most of the blue light is scattered away before it reaches us.  The remaining light is mostly red and orange, which is why sunrises and sunsets often appear reddish.
#
# **In summary:** Blue light is scattered more effectively than other colors of the rainbow by the tiny particles in Earth's atmosphere.  This scattered blue light is what we see when we look up at the sky.

# %%
prompt = """Create a numbered list of 10 items. Each item in the list should be a trend in the tech industry.

Each trend should be less than 5 words."""  # try your own prompt

# %%
responses = model.generate_content(prompt, stream=True)

# %%
for response in responses:
    print(response.text, end="")
# Out:
# Okay, here are 10 current trends in the tech industry, each described in under 5 words:
#
# 1.  **Artificial Intelligence Everywhere**
# 2.  **Cloud Computing Dominance**
# 3.  **Cybersecurity Mesh Architecture**
# 4.  **Metaverse/Extended Reality Expansion**
# 5.  **Low-Code/No-Code Development**
# 6.  **Sustainable Tech Focus**
# 7.  **Quantum Computing Advances**
# 8.  **Edge Computing Proliferation**
# 9.  **Web3/Blockchain Adoption**
# 10. **Automation Hyper-personalization**

# %% [markdown]
# ## Model parameters
#
# Every prompt you send to the model includes parameter values that control how the model generates a response. The model can generate different results for different parameter values. You can experiment with different model parameters to see how the results change.

# %%
generation_config = GenerationConfig(
    temperature=0.9,
    top_p=1.0,
    top_k=32,
    candidate_count=1,
    max_output_tokens=8192,
)

# %%
responses = model.generate_content(
    "Why is the sky blue?",
    generation_config=generation_config,
    stream=True,
)

# %%
for response in responses:
    print(response.text, end="")
# Out:
# The sky is blue due to a phenomenon called **Rayleigh scattering**. Here's a breakdown of what that means:
#
# *   **Sunlight and Colors:** Sunlight is actually made up of all the colors of the rainbow.
#
# *   **Entering the Atmosphere:** When sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen).
#
# *   **Scattering:** This collision causes the sunlight to scatter in different directions.
#
# *   **Wavelength and Scattering:** The amount of scattering depends on the wavelength (color) of the light. Shorter wavelengths, like blue and violet, are scattered much more strongly than longer wavelengths like red and orange.
#
# *   **Why Blue, Not Violet?** Although violet light is scattered even more than blue, there are a couple of reasons why we see a blue sky:
#     *   The sun emits less violet light than blue light.
#     *   Our eyes are more sensitive to blue light than violet light. Also our atmosphere absorbs some violet light.
#
# *   **The Result:** Since blue light is scattered more effectively, it's scattered all over the sky. When we look up, we see this scattered blue light coming from all directions, making the sky appear blue.
#
# **In simpler terms:**
#
# Imagine throwing a bunch of different-sized marbles (colors of light) at a bunch of tiny pebbles (air molecules). The smaller marbles (blue and violet light) will bounce off in all directions more easily than the bigger marbles (red and orange light). That's why you see the smaller marbles (blue light) all over the place when you look around.
#
# Therefore, the sky appears blue because blue light is scattered more than other colors by the air molecules in the Earth's atmosphere.

# %%
source_img_data = requests.get('https://drive.google.com/uc?export=view&id=15ddcn-AIxpvRdWcFGvIr77XLWdo4Maof').content

# %%
with open('coffee_maker_part.png', 'wb') as handler:
  handler.write(source_img_data)

# %%
# !pip uninstall langchain-google-vertexai -y -q

# %%
# !pip install langchain-google-vertexai==2.0.5 -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.3/438.3 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.7/130.7 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 11.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.2.9 requires langchain-core<0.3.0,>=0.2.22, but you have langchain-core 0.3.61 which is incompatible.
# langchain-text-splitters 0.2.2 requires langchain-core<0.3.0,>=0.2.10, but you have langchain-core 0.3.61 which is incompatible.
# langchain-nvidia-ai-endpoints 0.1.1 requires langchain-core<0.3,>=0.1.27, but you have langchain-core 0.3.61 which is incompatible.
# langchain-openai 0.1.8 requires langchain-core<0.3,>=0.2.2, but you have langchain-core 0.3.61 which is incompatible.
# langchain 0.2.10 requires langchain-core<0.3.0,>=0.2.22, but you have langchain-core 0.3.61 which is incompatible.
# ragstack-ai-langchain 1.4.0 requires langchain-core==0.2.22, but you have langchain-core 0.3.61 which is incompatible.
# langchain-google-genai 1.0.6 requires langchain-core<0.3,>=0.2.2, but you have langchain-core 0.3.61 which is incompatible.
# langchain-astradb 0.3.3 requires langchain-core<0.3,>=0.1.31, but you have langchain-core 0.3.61 which is incompatible.

# %%
# %pip uninstall pydantic -y -q

# %%
# %pip install pydantic==2.9.0 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.9/146.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.3/434.3 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unstructured-client 0.35.0 requires pydantic>=2.11.2, but you have pydantic 2.9.0 which is incompatible.
# langchain 0.2.10 requires langchain-core<0.3.0,>=0.2.22, but you have langchain-core 0.3.61 which is incompatible.
# ragstack-ai-langchain 1.4.0 requires langchain-core==0.2.22, but you have langchain-core 0.3.61 which is incompatible.
# langchain-google-genai 1.0.6 requires langchain-core<0.3,>=0.2.2, but you have langchain-core 0.3.61 which is incompatible.
# langchain-astradb 0.3.3 requires langchain-core<0.3,>=0.1.31, but you have langchain-core 0.3.61 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# albumentations 2.0.6 requires pydantic>=2.9.2, but you have pydantic 2.9.0 which is incompatible.

# %%
import sys
print(sys.version)
# Out:
# 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]

# %%
#!pip install --upgrade langchain-google-vertexai google-cloud-aiplatform -q
#!pip install --upgrade langchain-google-vertexai langchain-core google-cloud-aiplatform -q

# %%
# !pip install --upgrade --force-reinstall \
    langchain langchain-core langchain-community langchain-google-vertexai google-cloud-aiplatform -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 33.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 70.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.2/361.2 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.5/253.5 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.3/394.3 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.3/196.3 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.3/360.3 kB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.9/398.9 kB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 24.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 40.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 84.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.3/147.3 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 583.9/583.9 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 106.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.7/223.7 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.5/232.5 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 10.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.1/358.1 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 97.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 5.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.4 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.4 which is incompatible.
# langchain-nvidia-ai-endpoints 0.1.1 requires langchain-core<0.3,>=0.1.27, but you have langchain-core 0.3.61 which is incompatible.
# llama-index-legacy 0.9.48.post4 requires tenacity<9.0.0,>=8.2.0, but you have tenacity 9.1.2 which is incompatible.
# langchain-openai 0.1.8 requires langchain-core<0.3,>=0.2.2, but you have langchain-core 0.3.61 which is incompatible.
# llama-index-core 0.10.57 requires numpy<2.0.0, but you have numpy 2.2.6 which is incompatible.
# llama-index-core 0.10.57 requires tenacity!=8.4.0,<9.0.0,>=8.2.0, but you have tenacity 9.1.2 which is incompatible.
# ragstack-ai-colbert 1.0.6 requires pyarrow==14.0.1, but you have pyarrow 19.0.1 which is incompatible.
# ragstack-ai-langchain 1.4.0 requires langchain==0.2.10, but you have langchain 0.3.25 which is incompatible.
# ragstack-ai-langchain 1.4.0 requires langchain-community==0.2.9, but you have langchain-community 0.3.24 which is incompatible.
# ragstack-ai-langchain 1.4.0 requires langchain-core==0.2.22, but you have langchain-core 0.3.61 which is incompatible.
# langchain-google-genai 1.0.6 requires langchain-core<0.3,>=0.2.2, but you have langchain-core 0.3.61 which is incompatible.
# langchain-astradb 0.3.3 requires langchain-core<0.3,>=0.1.31, but you have langchain-core 0.3.61 which is incompatible.
# langchain-astradb 0.3.3 requires numpy<2,>=1, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.2 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.2.1 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.

# %%
from langchain_google_vertexai import ChatVertexAI

# %%
from langchain.schema.messages import HumanMessage
from PIL import Image, ImageFile
import os, sys

# %%
# Initialize ChatVertexAI with explicit project and location
from langchain_google_vertexai import ChatVertexAI
chat = ChatVertexAI(model_name="gemini-2.0-flash-001", project=PROJECT_ID, location=LOCATION)

# %%
import base64

# Read the image file as bytes
with open("coffee_maker_part.png", "rb") as f:
    image_bytes = f.read()


# Encode the image bytes as a base64 string
base64_image = base64.b64encode(image_bytes).decode("utf-8")

# Update the image_message to use the base64 encoded string
image_message = {
    "type": "image_url",
    "image_url": {"url": f"data:image/png;base64,{base64_image}"},
}
text_message = {
    "type": "text",
    "text": "What is this image? Share a link to purchase a replacement",
}

# %%
message = HumanMessage(content=[text_message, image_message])

# %%
output = chat([message])
# Out:
# <ipython-input-35-ef6c7459325c>:1: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   output = chat([message])

# %%
print(output.content)
# Out:
# This is a **portafilter basket** for an espresso machine. It holds the ground coffee during the espresso brewing process.
#
# To find the correct replacement, you'll need to know:
#
# 1.  **The size of your portafilter basket.** The most common sizes are 58mm, 53mm, 51mm, and 49mm.
# 2.  **Whether you need a single, double, or triple shot basket.** This refers to the amount of coffee it can hold.
# 3.  **The brand and model of your espresso machine.** Some machines require specific baskets.
#
# Here's a link to a generic 58mm basket on Amazon, but it is important to measure and specify the machine brand/model to ensure a good fit. [https://www.amazon.com/Portafilter-Espresso-Stainless-Replacement-Accessories/dp/B09972G58L](https://www.amazon.com/Portafilter-Espresso-Stainless-Replacement-Accessories/dp/B09972G58L)

# %%
import pandas as pd

d = {'name': ["Saucer", "Saucer Ceramic", "Milk Jug Assembly", "Handle Steam Wand Kit (New Version From 0735 PDC)", "Spout Juice Small (From 0637 to 1041 PDC)", "Cleaning Steam Wand", "Jug Frothing", "Spoon Tamping 50mm", "Collar Grouphead 50mm", "Filter 2 Cup Dual Wall 50mm", "Filter 1 Cup 50mm", "Water Tank Assembly", "Portafilter Assembly 50mm", "Milk Jug Assembly", "Filter 2 Cup 50mm" ],
# 8   https://assets.breville.com/cdn-cgi/image/widt...
# 9   https://www.breville.com/content/dam/breville/...
# 10  https://www.breville.com/content/dam/breville/...
# 11  https://www.breville.com/content/dam/breville/...
# 12  https://www.breville.com/content/dam/breville/...
# 13  https://www.breville.com/content/dam/breville/...
# 14  https://www.breville.com/content/dam/breville/...

# %%
import vertexai, json, requests
from vertexai.preview.vision_models import MultiModalEmbeddingModel, Image
from astrapy.db import AstraDB, AstraDBCollection
from google.colab import files
# Out:
# <ipython-input-38-f146adbe4615>:3: DeprecatedWarning: All of 'astrapy.core.*', 'astrapy.api.*', 'astrapy.db.*' and 'astrapy.ops.*' is deprecated as of 1.5.0 and will be removed in 2.0.0. Please refer to https://docs.datastax.com/en/astra-db-serverless/api-reference/dataapiclient.html to start the (recommended) path forward to the current API, and to https://github.com/datastax/astrapy?tab=readme-ov-file#appendix-b-compatibility-with-pre-100-library for details on the deprecated modules.
#   from astrapy.db import AstraDB, AstraDBCollection

# %%
vertexai.init(project=PROJECT_ID, location=LOCATION)
model = MultiModalEmbeddingModel.from_pretrained("multimodalembedding@001")

# %%
# Initialize our vector db
astra_db = AstraDB(token= ASTRA_DB_APPLICATION_TOKEN, api_endpoint= ASTRA_DB_API_ENDPOINT)

# %%
collection = astra_db.create_collection(collection_name="coffee_shop_ecommerce", dimension=1408)

# %%
for i in range(len(df)):
  name = df.loc[i, "name"]
  image = df.loc[i, "image"]
  price = df.loc[i, "price"]
  url = df.loc[i, "url"]

  # Download this product's image and save it to the Colab filesystem.
  # In a production system this binary data would be stored in Google Cloud Storage
  img_data = requests.get(image).content
  with open(f'{name}.png', 'wb') as handler:
    handler.write(img_data)

  # load the image from filesystem and compute the embedding value
  img = Image.load_from_file(f'{name}.png')
  print(img)
  embeddings = model.get_embeddings(image=img, contextual_text=name)

  try:
    # add to the AstraDB Vector Database
    collection.insert_one({
        "_id": i,
        "name": name,
        "image": image,
        "url": url,
        "price": price,
        "$vector": embeddings.image_embedding,
      })
  except Exception as error:
    # if you've already added this record, skip the error message
    error_info = json.loads(str(error))
    if error_info[0]['errorCode'] == "DOCUMENT_ALREADY_EXISTS":
      print("Document already exists in the database.  Skipping.")
# Out:
# <vertexai.vision_models.Image object at 0x7a0ca22b2f50>
# <vertexai.vision_models.Image object at 0x7a0ca161d290>
# <vertexai.vision_models.Image object at 0x7a0ca0cd3850>
# <vertexai.vision_models.Image object at 0x7a0ca0cd21d0>
# <vertexai.vision_models.Image object at 0x7a0ca0cef3d0>
# <vertexai.vision_models.Image object at 0x7a0ca161d290>
# <vertexai.vision_models.Image object at 0x7a0ca0ea62d0>
# <vertexai.vision_models.Image object at 0x7a0ca0cec110>
# <vertexai.vision_models.Image object at 0x7a0ca0d09d90>
# <vertexai.vision_models.Image object at 0x7a0ca1181010>
# <vertexai.vision_models.Image object at 0x7a0ca11811d0>
# <vertexai.vision_models.Image object at 0x7a0ca0cd1b10>
# <vertexai.vision_models.Image object at 0x7a0ca0d08d50>
# <vertexai.vision_models.Image object at 0x7a0ca0cd1810>
#  0.00741417287,
#  0.0109892776,
#  -0.0386588722,
#  -0.0234071109,
#  0.0027114728,
#  -0.0273525566,
#  0.0164901,
#  0.00269815419,
#  0.00527774403,
#  0.0120628774,
#  -0.0227058418,
#  -0.0150462622,
#  ...]

# %%
# Perform the vector search against AstraDB Vector
documents = collection.vector_find(
    embeddings.image_embedding,
    limit=3,
)

# %%
documents
# Out:
# [{'_id': 14,
#   'name': 'Filter 2 Cup 50mm',
#   'image': 'https://www.breville.com/content/dam/breville/us/catalog/products/images/sp0/sp0000166/tile.jpg',
#   'url': 'https://www.breville.com/us/en/parts-accessories/parts/sp0000166.html?sku=SP0000166',
#   'price': '11.95',
#   '$similarity': 0.91381896},
#  {'_id': 9,
#   'name': 'Filter 2 Cup Dual Wall 50mm',
#   'image': 'https://www.breville.com/content/dam/breville/au/catalog/products/images/sp0/sp0003231/tile.jpg',
#   'url': 'https://www.breville.com/us/en/parts-accessories/parts/sp0003231.html?sku=SP0003231',
#   'price': '12.95',
#   '$similarity': 0.9138187},
#  {'_id': 10,
#   'name': 'Filter 1 Cup 50mm',
#   'image': 'https://www.breville.com/content/dam/breville/au/catalog/products/images/sp0/sp0003230/tile.jpg',
#   'url': 'https://www.breville.com/us/en/parts-accessories/parts/sp0003230.html?sku=SP0003230',
#   'price': '12.95',
#   '$similarity': 0.91185796}]

# %%
related_products_csv = "name, image, price, url\n"
for doc in documents:
  related_products_csv += f"{doc['name']}, {doc['image']}, {doc['price']}, {doc['url']},\n"

# %%
print(related_products_csv)
# Out:
# name, image, price, url
# Filter 2 Cup 50mm, https://www.breville.com/content/dam/breville/us/catalog/products/images/sp0/sp0000166/tile.jpg, 11.95, https://www.breville.com/us/en/parts-accessories/parts/sp0000166.html?sku=SP0000166,
# Filter 2 Cup Dual Wall 50mm, https://www.breville.com/content/dam/breville/au/catalog/products/images/sp0/sp0003231/tile.jpg, 12.95, https://www.breville.com/us/en/parts-accessories/parts/sp0003231.html?sku=SP0003231,
# Filter 1 Cup 50mm, https://www.breville.com/content/dam/breville/au/catalog/products/images/sp0/sp0003230/tile.jpg, 12.95, https://www.breville.com/us/en/parts-accessories/parts/sp0003230.html?sku=SP0003230,

# %%
image_message = {
    "type": "image_url",
    "image_url": {"url": "/content/coffee_maker_part.png"},
}
text_message = {
    "type": "text",
    "text": f"What we have in this image? Share the URL and price to purchase a replacement. Here are related products {related_products_csv}",
}

# %%
message = HumanMessage(content=[text_message, image_message])
message
# Out:
# HumanMessage(content=[{'type': 'text', 'text': 'What we have in this image? Share the URL and price to purchase a replacement. Here are related products name, image, price, url\nFilter 2 Cup 50mm, https://www.breville.com/content/dam/breville/us/catalog/products/images/sp0/sp0000166/tile.jpg, 11.95, https://www.breville.com/us/en/parts-accessories/parts/sp0000166.html?sku=SP0000166,\nFilter 2 Cup Dual Wall 50mm, https://www.breville.com/content/dam/breville/au/catalog/products/images/sp0/sp0003231/tile.jpg, 12.95, https://www.breville.com/us/en/parts-accessories/parts/sp0003231.html?sku=SP0003231,\nFilter 1 Cup 50mm, https://www.breville.com/content/dam/breville/au/catalog/products/images/sp0/sp0003230/tile.jpg, 12.95, https://www.breville.com/us/en/parts-accessories/parts/sp0003230.html?sku=SP0003230,\n'}, {'type': 'image_url', 'image_url': {'url': '/content/coffee_maker_part.png'}}], additional_kwargs={}, response_metadata={})

# %%
chat = ChatVertexAI(model_name="gemini-2.0-flash-001")

# %%
from langchain.schema import HumanMessage

# Sample message content
message = HumanMessage(content=[text_message, image_message])  # image_message might be optional

# Graceful handling
text = None
image = None

for item in message.content:
    if isinstance(item, str):
        text = item
    elif hasattr(item, 'type') and item.type == 'image_url':
        image = item

# Now use text and image safely
if text:
    print("Text message:", text)

if image:
    print("Image URL:", image.url)
else:
    print("No image provided.")
# Out:
# No image provided.

# %%
content = [text_message]
if image_message is not None:
    content.append(image_message)

message = HumanMessage(content=content)

# %%
print(output.content)
# Out:
# This is a **portafilter basket** for an espresso machine. It holds the ground coffee during the espresso brewing process.
#
# To find the correct replacement, you'll need to know:
#
# 1.  **The size of your portafilter basket.** The most common sizes are 58mm, 53mm, 51mm, and 49mm.
# 2.  **Whether you need a single, double, or triple shot basket.** This refers to the amount of coffee it can hold.
# 3.  **The brand and model of your espresso machine.** Some machines require specific baskets.
#
# Here's a link to a generic 58mm basket on Amazon, but it is important to measure and specify the machine brand/model to ensure a good fit. [https://www.amazon.com/Portafilter-Espresso-Stainless-Replacement-Accessories/dp/B09972G58L](https://www.amazon.com/Portafilter-Espresso-Stainless-Replacement-Accessories/dp/B09972G58L)
